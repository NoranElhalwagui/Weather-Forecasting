# %%
import pandas as pd

df = pd.read_csv("data/weather_history.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38640 entries, 0 to 38639
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       38640 non-null  object
#  1   temperature_2m             38640 non-null  float64
#  2   relative_humidity_2m       38640 non-null  float64
#  3   precipitation              38640 non-null  float64
#  4   wind_speed_10m             38640 non-null  float64
#  5   wind_direction_10m         38640 non-null  float64
#  6   precipitation_probability  8901 non-null   float64
#  7   cloud_cover                38640 non-null  float64
#  8   wind_gusts_10m             38640 non-null  float64
#  9   visibility                 38640 non-null  float64
#  10  weather_code               38640 non-null  float64
#  11  apparent_temperature       38640 non-null  float64
#  12  dew_point_2m               38640 non-null  float64
# dtypes: float64(12), object(1)
# memory usage: 3.8+ MB

# %%
df.isna().sum()
# Out:
# date                             0
# temperature_2m                   0
# relative_humidity_2m             0
# precipitation                    0
# wind_speed_10m                   0
# wind_direction_10m               0
# precipitation_probability    29739
# cloud_cover                      0
# wind_gusts_10m                   0
# visibility                       0
# weather_code                     0
# apparent_temperature             0
# dew_point_2m                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.plot(df["date"], df["temperature_2m"])
plt.title("Temperature Over Time")
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.show()
